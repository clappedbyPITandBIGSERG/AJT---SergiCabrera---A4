# %% [markdown]
# Exercici 1

# %%
import math
def Ct(C0,k,t):
    Ct = C0*math.exp(-k*t)
    print(Ct)
    return Ct

# %%
for t in range (26):
    Ct(200,3,t)
# Out:
# 200.0
# 9.95741367357279
# 0.4957504353332717
# 0.024681960817335914
# 0.001228842470665642
# 6.118046410036516e-05
# 3.045995948942526e-06
# 1.5165120855823812e-07
# 7.550269088558196e-09
# 3.7590576330781667e-10
# 1.8715245937680348e-11
# 9.317772290206795e-13
# 4.639045660487139e-14
# 2.3096448346031573e-15
# 1.149904452858712e-16
# 5.725037161098787e-18
# 2.85032816548187e-19
# 1.4190948324569408e-20
# 7.065257144401614e-22
# 3.5175844048486233e-23
# 1.751302152539304e-24
# 8.719220000126162e-26
# 4.341044022607279e-27
# 2.161278555414557e-28
# 1.0760372320042277e-29
# 5.357273923616155e-31

# %% [markdown]
# Exercici 2

# %%
def analitzar_element(llista, element):
    nombre_apareix = 0
    for element in llista:
    apareix= True
    No_apareix = False 
     if element
